# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("/kaggle/input/age-data/age_status.csv")
df.head()
# Out:
#    age  status
# 0   21     0.0
# 1   33     1.0
# 2   24     0.0
# 3   28     1.0
# 4   17     0.0

# %%
df.isnull().sum()
# Out:
# age       0
# status    1
# dtype: int64

# %%
replace = df['status'].mode()[0]
df.status = df.status.fillna(replace)
df.isnull().sum()
# Out:
# age       0
# status    0
# dtype: int64

# %%
X = df[["age"]]
y = df["status"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
clf.score(X_test, y_test)
# Out:
# 1.0
