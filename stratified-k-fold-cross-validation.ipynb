# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("/kaggle/input/play-tennis-data/play_tennis_100_unique.csv")
df.head()
# Out:
#     Outlook  Temp Humidity   Wind Play
# 0      Rain  Mild     High   True   No
# 1  Overcast  Cool     High  False  Yes
# 2  Overcast   Hot     High   True  Yes
# 3     Sunny   Hot     High  False   No
# 4     Sunny  Cool     High  False   No

# %%
le = LabelEncoder()
df.Outlook = le.fit_transform(df.Outlook)
df.Temp = le.fit_transform(df.Temp)
df.Humidity = le.fit_transform(df.Humidity)
df.Wind = le.fit_transform(df.Wind)

# %%
df.head()
# Out:
#    Outlook  Temp  Humidity  Wind Play
# 0        1     2         0     1   No
# 1        0     0         0     0  Yes
# 2        0     1         0     1  Yes
# 3        2     1         0     0   No
# 4        2     0         0     0   No

# %%
X = df.drop(columns = "Play")
y = df.Play

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.score(X_test, y_test)
# Out:
# 1.0

# %%
skf = StratifiedKFold(n_splits = 5, random_state = 42, shuffle = True)
skf_scores = cross_val_score(clf, X, y, cv = skf)
skf_scores
# Out:
# array([1., 1., 1., 1., 1.])
