# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
# Example dataset
data = {
    "Age": [18, 22, 30, 40, 50],
    "Salary": [20000, 35000, 50000, 70000, 100000]
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#    Age  Salary
# 0   18   20000
# 1   22   35000
# 2   30   50000
# 3   40   70000
# 4   50  100000

# %%
# Initialize StandardScaler
scaler = StandardScaler()

# Fit and transform
scaled = scaler.fit_transform(df)
print(scaled)
# Out:
# [[-1.19349009 -1.25320103]
#  [-0.85249292 -0.71611487]
#  [-0.17049858 -0.17902872]
#  [ 0.68199434  0.53708616]
#  [ 1.53448726  1.61125847]]

# %%
# Put back into DataFrame
df_scaled = pd.DataFrame(scaled, columns=df.columns)

print("\nDataFrame after Standardization (Z-score Scaling):")
print(df_scaled)
# Out:
# DataFrame after Standardization (Z-score Scaling):
#         Age    Salary
# 0 -1.193490 -1.253201
# 1 -0.852493 -0.716115
# 2 -0.170499 -0.179029
# 3  0.681994  0.537086
# 4  1.534487  1.611258
